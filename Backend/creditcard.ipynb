# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Exploratory Data Analysis: Credit Card Fraud Dataset"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "import os\n",
    "\n",
    "# Load dataset\n",
    "DATA_FILE = os.path.join(os.path.dirname('__file__'), 'creditcard.csv')\n",
    "df = pd.read_csv(DATA_FILE)\n",
    "df.head()"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Dataset Overview"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "print(f\"Dataset shape: {df.shape}\")\n",
    "print(df.info())\n",
    "print(df['Class'].value_counts())"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Visualizing Class Distribution"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "sns.countplot(x='Class', data=df)\n",
    "plt.title('Class Distribution')\n",
    "plt.show()"
   ],
   "execution_count": null,
   "outputs": []
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 24
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Exploratory Data Analysis: Credit Card Fraud Dataset"
#       8    ]
#       9   },
#      10   {
#      11    "cell_type": "code",
#      12    "metadata": {},
#      13    "source": [
#      14     "import pandas as pd\n",
#      15     "import matplotlib.pyplot as plt\n",
#      16     "import seaborn as sns\n",
#      17     "import os\n",
#      18     "\n",
#      19     "# Load dataset\n",
#      20     "DATA_FILE = os.path.join(os.path.dirname('__file__'), 'creditcard.csv')\n",
#      21     "df = pd.read_csv(DATA_FILE)\n",
#      22     "df.head()"
#      23    ],
# ---> 24    "execution_count": null,
#      25    "outputs": []
#      26   },
#      27   {
#      28    "cell_type": "markdown",
#      29    "metadata": {},
#      30    "source": [
#      31     "## Dataset Overview"
#      32    ]
#      33   },
#      34   {
#      35    "cell_type": "code",
#      36    "metadata": {},
#      37    "source": [
#      38     "print(f\"Dataset shape: {df.shape}\")\n",
#      39     "print(df.info())\n",
#      40     "print(df['Class'].value_counts())"
#      41    ],
#      42    "execution_count": null,
#      43    "outputs": []
#      44   },
#      45   {
#      46    "cell_type": "markdown",
#      47    "metadata": {},
#      48    "source": [
#      49     "## Visualizing Class Distribution"
#      50    ]
#      51   },
#      52   {
#      53    "cell_type": "code",
#      54    "metadata": {},
#      55    "source": [
#      56     "sns.countplot(x='Class', data=df)\n",
#      57     "plt.title('Class Distribution')\n",
#      58     "plt.show()"
#      59    ],
#      60    "execution_count": null,
#      61    "outputs": []
#      62   }
#      63  ],
#      64  "metadata": {
#      65   "kernelspec": {
#      66    "display_name": "Python 3",
#      67    "language": "python",
#      68    "name": "python3"
#      69   },
#      70   "language_info": {
#      71    "name": "python",
#      72    "version": "3.10"
#      73   }
#      74  },
#      75  "nbformat": 4,
#      76  "nbformat_minor": 5
#      77 }
#
# NameError: name 'null' is not defined
